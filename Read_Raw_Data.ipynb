# %% [markdown]
# 导入运行库

# %%
import pandas as pd

# %% [markdown]
# 读取前十行数据

# %%
df = pd.read_csv('./Data/川菜.csv', nrows=15)
print(df)
print(type(df))
# Out:
#                                         comment level
# 0   这家川菜外卖太惊艳了！麻婆豆腐麻辣鲜香，米饭都多吃了两碗，配送也超快，包装严实不洒漏。  优质店铺
# 1               水煮牛肉分量足，肉质嫩滑，辣得刚刚好，绝对是川菜爱好者的福音！  优质店铺
# 2                 宫保鸡丁酸甜微辣，花生脆香，和堂食味道几乎没差，强烈推荐！  优质店铺
# 3                    鱼香肉丝配米饭绝了！酱汁浓郁，酸辣开胃，下次还会点。  优质店铺
# 4                      回锅肉肥而不腻，蒜苗清香，辣味正宗，吃得超满足！  优质店铺
# 5             夫妻肺片很入味，红油香而不燥，配啤酒一流（虽然外卖不能送酒哈哈）。  优质店铺
# 6                      酸菜鱼汤底酸辣开胃，鱼片嫩滑无刺，连汤都喝光了！  优质店铺
# 7                        干锅花菜火候刚好，香辣脆爽，配米饭太下饭了。  优质店铺
# 8           辣子鸡块里鸡肉外酥里嫩，辣椒香而不焦，就是辣椒太多得挑着吃，但很过瘾！  优质店铺
# 9          毛血旺料超足！毛肚、鸭血、黄喉都有，麻辣鲜香，吃得满头大汗还停不下筷子。  优质店铺
# 10             口水鸡酱汁调得太棒了，芝麻香混合辣油，鸡肉嫩滑，夏天吃特别爽口。  优质店铺
# 11                    担担面酱香浓郁，微辣带麻，面条劲道，吃完还想舔碗！  优质店铺
# 12                     泡椒凤爪酸辣爽脆，作为前菜太合适了，解腻又开胃。  优质店铺
# 13        香辣蟹虽然外卖有点挑战，但他们家处理得很好，蟹肉新鲜，酱汁浓郁，值得一试！  优质店铺
# 14                  蒜泥白肉肥瘦相间，蒜香浓郁，配上秘制酱料，一点都不腻。  优质店铺
# <class 'pandas.core.frame.DataFrame'>
